# %%
import numpy as np
data = np.load("/home/anibal/binary_source/results/scan_u0_tE1000/"+"scan_kepler_u0_018.npz")
data.files
# Out:
# ['t',
#  'P_grid',
#  'xiE_of_P',
#  'a_AU_of_P',
#  'RMS',
#  'MAXABS',
#  'intL1',
#  'DT0',
#  'DU0',
#  'DTE',
#  'SUCCESS',
#  'BEST_T0U0TE',
#  't0_interval',
#  'tE_interval',
#  'CHEB_COEFF_TRUTH',
#  'CHEB_COEFF_FIT',
#  'truth',
#  'A_truth_grid',
#  'A_fit_grid',
#  'F_truth_grid',
#  'F_fit_grid']

# %%
print(data["t"].shape)
print(data["A_truth_grid"].shape)
# Out:
# (100800,)
# (60, 100800)

# %%
import matplotlib.pyplot as plt

plt.plot(data["t"],data["A_truth_grid"][0])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       1 import pandas as pd
#       2 pd.read_csv("/home/anibal/simdr2_cache.csv")
# ----> 4 df_pairs = build_mu_rel_pairs(df_raw, N, offset=0.1, min_D=1.0, random_state=None)
#
# NameError: name 'build_mu_rel_pairs' is not defined
